# %%
# Standard Imports
import numpy as np
from time import time
from matplotlib import pyplot as plt
import os


from pyspecter.SPECTER import SPECTER
from pyspecter.Observables import Observable
# from pyspecter.SpecialObservables import SpecialObservables

# Utils
from pyspecter.utils.data_utils import load_cmsopendata, load_triangles
from pyspecter.utils.plot_utils import newplot, plot_event

# Jax
from jax import grad, jacobian, jit
import jax.numpy as jnp
from jax import random

# SPECTER
from pyspecter.SpectralEMD_Helper import compute_spectral_representation
# Out:
# 2023-11-05 05:00:07.368785: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# /home/rikab/miniconda3/envs/SHAPER/lib/python3.8/site-packages/ot/backend.py:2998: UserWarning: To use TensorflowBackend, you need to activate the tensorflow numpy API. You can activate it by running:
# from tensorflow.python.ops.numpy_ops import np_config
# np_config.enable_numpy_behavior()
#   register_backend(TensorflowBackend())

# %% [markdown]
# # Dataset

# %%
# Parameters 
R = 0.1
this_dir = ""
this_study = "cmsopendata"


dataset_open, sim_weights, k = load_cmsopendata("~/.energyflow/", "sim", 475, 525, 1.9, 2, pad = 75, n = 100)
triangle_events, triangle_indices = load_triangles(180, 180, R = 1.0, return_indices=True)

dataset = dataset_open
# Out:
# Max # of particles: 113

# %%
from pyspecter.SpectralEMD_Helper import ds2_events1_spectral2
import jax.example_libraries.optimizers as jax_opt
from jax.example_libraries import optimizers
import jax
import jax.lax as lax
import tqdm

# Compile 
compiled_compute_spectral_representation = jit(compute_spectral_representation)




def initialize(event, N, seed):

    return {"Radius" : R, "Lambda" : 0}


def sample_circle(params, N, seed):

    key = jax.random.PRNGKey(seed)
    key_theta, key_r = jax.random.split(key)

    thetas = jax.random.uniform(key_theta, shape=(N,), minval=0., maxval=2*jnp.pi)
    rs = jax.random.uniform(key_r, shape=(N,), minval=0., maxval=1)

    # Compute x and y coordinates of the sampled points on the circle
    x = params["Radius"] * jnp.sqrt(rs) * jnp.cos(thetas)
    y = params["Radius"] * jnp.sqrt(rs) * jnp.sin(thetas)
    
    event = jnp.column_stack([jnp.ones(N) * params["Lambda"] / N, x, y])
    e0 = jnp.array([(1 - params["Lambda"], 0, 0), ])
    event = jnp.concatenate((event, e0), axis = 0)

    
    return event

sample_circle = jax.jit(sample_circle, static_argnums=(1,))

@jax.jit
def project(params):

    radius = params["Radius"]
    params["Radius"] = jnp.maximum(radius, 0.)
    return params
    



def train_step(epoch, spectral_event, params):

    shape_event = sample_circle(params, 25, seed = epoch)
    sEMDS = jax.checkpoint(ds2_events1_spectral2)(shape_event, spectral_event)
    return sEMDS

gradient_train_step = jax.jit(jax.jacfwd(train_step, argnums = 2))
train_step  = jax.jit(train_step)

vmapped_compute_spectral_representation = jax.vmap(compiled_compute_spectral_representation, in_axes = (0,))
vmapped_train_step = jax.vmap(train_step, in_axes = (None, 0, 0))
vmapped_gradient_train_step = jax.vmap(gradient_train_step, in_axes = (None, 0, 0))
vmapped_initialize = jax.vmap(initialize, in_axes = (0, None, None))
vmapped_project = jax.vmap(project, in_axes = (0,))



# Chain rule
few_to_many_grad = jax.grad(sample_circle, argnums=0)
many_to_few = jax.grad(ds2_events1_spectral2)
def my_gradient(epoch, spectral_event, params):
    shape_event = sample_circle(params, 25, seed = epoch)
    d1 = few_to_many_grad(params, 25, seed = epoch)
    d2 = many_to_few(shape_event, spectral_event)
    return jnp.dot(d1, d2)
vmapped_my_gradient = jax.vmap(my_gradient, in_axes = (0,))

@jax.jit
def finite_differences_gradient(epoch, spectral_event, params, epsilon=1e-2):
    """
    Compute the gradient of `loss_fn` with respect to `params` using finite differences.
    This version uses multiplicative epsilon and is JAX-compilable.
    
    Args:
        params (dict): A dictionary containing the parameters.
        loss_fn (callable): The loss function to compute the gradient of.
        x (array): The input data for the loss function.
        y (array): The output data for the loss function.
        epsilon (float, optional): The small relative change to apply to each parameter to calculate finite differences.
    
    Returns:
        dict: A dictionary of gradients for each parameter.
    """
    
    def get_perturbed_loss(delta):
        # Perturb each parameter by a small relative amount and evaluate the loss
        perturbed_params = jax.tree_map(lambda v: v * (1 + delta), params)
        return train_step(epoch, spectral_event, perturbed_params)

    # Compute the perturbed losses for positive and negative epsilon
    loss_plus_epsilon = get_perturbed_loss(epsilon)
    loss_minus_epsilon = get_perturbed_loss(-epsilon)

    # Use jax.tree_multimap to compute the gradient for each parameter
    gradients = jax.tree_map(
        lambda v: (loss_plus_epsilon - loss_minus_epsilon) / (2 * epsilon * v),
        params
    )
    
    return gradients


vmapped_finite_differences_gradient = jax.vmap(finite_differences_gradient, in_axes = (None, 0, 0))

def compute_single_event(event, learning_rate = 0.001, epochs = 150, finite_difference = True):

    spectral_event = compiled_compute_spectral_representation(event)
    params =   initialize(event, 75, seed = random.PRNGKey(0))

    # Optimizer
    opt_state = None
    opt_init, opt_update, get_params = jax_opt.adam(learning_rate)
    opt_state = opt_init(params)

    losses = np.zeros((epochs,))
    for epoch in tqdm.tqdm(range(epochs)):

        params = get_params(opt_state)
        params = project(params)
        
        sEMD = train_step(epoch, spectral_event, params)
        if finite_difference:
            grads = finite_differences_gradient(epoch, spectral_event, params)
        else:
            grads = gradient_train_step(epoch, spectral_event, params)
        opt_state = opt_update(epoch, grads, opt_state)

       # Apply the separate function to modify the parameters
        new_params = project(get_params(opt_state))

        # Manually modify the opt_state's parameters without resetting internal state
        opt_state = replace_params_in_state(opt_state, new_params)
        losses[epoch] = sEMD

    return jnp.min(losses), params, losses





def compute_events(events, learning_rate = 0.001, epochs = 150, finite_difference = True):

    spectral_event = vmapped_compute_spectral_representation(events)
    print(spectral_event.shape, events.shape)
    params =   vmapped_initialize(events, 75, 0)
    best_params = params.copy()

    # Optimizer
    opt_state = None
    opt_init, opt_update, get_params = jax_opt.adam(learning_rate)
    opt_state = opt_init(params)

    losses = np.ones((epochs,events.shape[0])) * 99999
    early_stopping_counter = 0

    for epoch in tqdm.tqdm(range(epochs)):

        params = get_params(opt_state)
        params = vmapped_project(params)
        
        sEMD = vmapped_train_step(epoch, spectral_event, params)
        if finite_difference:
            grads = vmapped_finite_differences_gradient(epoch, spectral_event, params)
        else:
            grads = vmapped_gradient_train_step(epoch, spectral_event, params)
        opt_state = opt_update(epoch, grads, opt_state)

       # Apply the separate function to modify the parameters
        new_params = vmapped_project(get_params(opt_state))

        # Manually modify the opt_state's parameters without resetting internal state
        opt_state = replace_params_in_state(opt_state, new_params)
        losses[epoch] = sEMD

        # if the loss has not changed in 10 epochs, stop
        if epoch > 10:
            if np.all(losses[epoch] >= losses[epoch-10]):
                early_stopping_counter += 1
            else:
                early_stopping_counter = 0

        if early_stopping_counter > 10:
            break

        # if the loss has decreased, save the parameters for each event
        for i in range(events.shape[0]):
            if i > 0 and sEMD[i] < losses[epoch-1,i]:
                for key in params.keys():
                    best_params[key] = best_params[key].at[i].set(params[key][i])

    
    return jnp.min(losses, axis = 0), best_params, losses



def replace_params_in_state(opt_state, new_params):
    if isinstance(opt_state, tuple) and len(opt_state) == 2 and isinstance(opt_state[0], dict):
        # This is the parameter tuple for Adam
        return (new_params, opt_state[1])
    elif isinstance(opt_state, tuple):
        # Unpack and modify recursively
        return tuple(replace_params_in_state(sub_state, new_params) for sub_state in opt_state)
    else:
        # Leaf node or unknown type, return unchanged
        return opt_state

# %%
test_event = sample_circle({"Radius" : 1, "Lambda" : 0.2}, 25, seed = 1)
print(test_event)
fig, ax = newplot()
plot_event(test_event, 1, ax)
# Out:
# [[ 0.008      -0.02000858  0.22020203]
#  [ 0.008       0.40492257  0.5773226 ]
#  [ 0.008       0.14387794  0.8951872 ]
#  [ 0.008      -0.12472679  0.22009392]
#  [ 0.008      -0.91081643 -0.3282946 ]
#  [ 0.008       0.22932173 -0.837026  ]
#  [ 0.008       0.41423044 -0.8568058 ]
#  [ 0.008       0.75097036 -0.2620747 ]
#  [ 0.008       0.5688677   0.18881598]
#  [ 0.008      -0.04843574 -0.44515216]
#  [ 0.008       0.22528468 -0.8037021 ]
#  [ 0.008       0.53849643 -0.19717243]
#  [ 0.008       0.17781933  0.00191147]
#  [ 0.008      -0.16355646  0.8879589 ]
#  [ 0.008       0.42614582 -0.5263089 ]
#  [ 0.008      -0.23248109 -0.34197208]
#  [ 0.008       0.6655523   0.7352973 ]
#  [ 0.008      -0.09023917  0.8463881 ]
#  [ 0.008       0.24725458  0.06142061]
#  [ 0.008      -0.04329485 -0.5665471 ]
#  [ 0.008      -0.314436   -0.33425897]
#  [ 0.008       0.10222325  0.36697924]
#  [ 0.008      -0.39641804  0.67699647]
#  [ 0.008      -0.6064254  -0.38252908]
#  [ 0.008       0.3419032  -0.2338266 ]
#  [ 0.8         0.          0.        ]]
# <Axes: xlabel='Rapidity', ylabel='Azimuthal Angle'>

# %%
def r_opt(event):

    # Spectral representation of the form (omega, 2*EE) with sorted omegas
    spectral_event = compute_spectral_representation(event)

    omegas = spectral_event[:,0]
    two_EE = spectral_event[:,1]
    E_tot = np.sum(two_EE)

    # Cumulative spectral function, inclusive and exclusive
    cumulative_spectral_function = np.cumsum(two_EE)
    cumulative_exclusive = cumulative_spectral_function - two_EE

    term1 = jnp.sin(jnp.pi / 2 / E_tot * (E_tot - cumulative_exclusive))
    term2 = jnp.sin(jnp.pi / 2 / E_tot * (E_tot - cumulative_spectral_function))
    
    return 2 * jnp.sum(omegas * (term1 - term2)) / jnp.pi

vmapped_r_opt = jax.vmap(r_opt, in_axes = (0,))

closed_form_r = vmapped_r_opt(dataset)

filename = f"{this_study}_closed_form_params.npy"
save_dir = os.path.join(this_dir, filename)
np.save(save_dir, closed_form_r)


def closed_form_sEMD(event, R):

    spectral_event = compute_spectral_representation(event)

    omegas = spectral_event[:,0]
    two_EE = spectral_event[:,1]

    return jnp.sum(omegas**2 * two_EE) - 2 * R**2

vmapped_closed_form_sEMD = jax.vmap(closed_form_sEMD, in_axes = (0, 0))
r = vmapped_closed_form_sEMD(dataset, closed_form_r)
filename = f"{this_study}_closed_form_sEMDs.npy"
save_dir = os.path.join(this_dir, filename)
np.save(save_dir, r)
# plt.hist(closed_form_r[:100] / shape_events["Radius"] * np.pi)

# %%
fig, ax = newplot()
circle = sample_circle({"Radius" : 1.0}, 50, 0)
print(compute_single_event(circle,learning_rate=0.1, finite_difference=False))
print(r_opt(circle))

plot_event(circle, 1, ax)

spectral_circle = compute_spectral_representation(circle)
print(spectral_circle)
plt.plot(spectral_circle[:,0], np.cumsum(spectral_circle[:,1]))
plt.plot(spectral_circle[:,0], 2 * 1 *  np.arcsin(spectral_circle[:,0] / 2) / np.pi)
# Out:
# 100%|██████████| 150/150 [00:04<00:00, 34.34it/s]
# (Array(0.00055909, dtype=float32), {'Radius': Array(1.0130059, dtype=float32)}, array([1.60072446e+00, 1.25309491e+00, 9.78484631e-01, 7.47225285e-01,
#        5.07918119e-01, 3.22735071e-01, 1.92805529e-01, 1.27021313e-01,
#        3.76937389e-02, 9.37438011e-03, 1.51729584e-03, 1.54423714e-02,
#        3.85637283e-02, 6.15735054e-02, 9.14831161e-02, 1.08498096e-01,
#        1.35352135e-01, 1.43227100e-01, 1.02063656e-01, 9.29546356e-02,
#        1.15536690e-01, 6.47139549e-02, 8.36567879e-02, 6.86564445e-02,
#        2.81248093e-02, 3.44829559e-02, 1.28955841e-02, 9.31453705e-03,
#        2.53438950e-03, 4.67801094e-03, 5.75685501e-03, 2.25830078e-03,
#        6.78396225e-03, 1.52626038e-02, 1.36632919e-02, 2.47170925e-02,
#        1.74643993e-02, 2.33018398e-02, 5.47430515e-02, 2.65259743e-02,
#        2.18245983e-02, 9.65142250e-03, 3.52191925e-03, 6.52384758e-03,
#        7.30752945e-03, 2.05659866e-03, 1.92980766e-02, 3.71122360e-03,
#        3.17716599e-03, 4.09841537e-03, 9.38463211e-03, 7.40861893e-03,
#        6.84690475e-03, 8.13436508e-03, 2.40135193e-03, 7.57789612e-03,
#        4.36306000e-03, 8.26644897e-03, 2.61664391e-03, 1.25813484e-03,
#        2.21705437e-03, 5.61070442e-03, 2.74801254e-03, 6.20365143e-04,
#        1.68085098e-03, 1.64461136e-03, 1.53088570e-03, 1.06859207e-03,
#        7.20024109e-04, 7.14635849e-03, 2.89511681e-03, 9.71078873e-04,
#        6.19888306e-04, 6.71648979e-03, 6.82353973e-04, 1.66392326e-03,
#        1.20501518e-02, 1.34806633e-02, 3.29494476e-03, 8.36873055e-03,
#        2.40826607e-03, 4.04095650e-03, 2.21514702e-03, 4.36019897e-03,
#        2.71582603e-03, 4.30870056e-03, 4.73499298e-03, 2.62022018e-03,
#        6.23846054e-03, 1.53517723e-03, 1.53970718e-03, 1.14226341e-03,
#        4.11224365e-03, 2.52175331e-03, 9.82522964e-04, 2.03776360e-03,
#        1.14393234e-03, 9.17124748e-03, 5.02347946e-03, 9.83667374e-03,
#        1.13892555e-03, 9.48357582e-03, 1.68538094e-03, 2.17223167e-03,
#        3.48567963e-03, 1.90258026e-03, 2.31170654e-03, 3.73101234e-03,
#        2.78472900e-03, 2.78997421e-03, 2.16555595e-03, 4.95076180e-03,
#        3.35502625e-03, 9.36985016e-04, 1.91068649e-03, 1.75786018e-03,
#        4.57334518e-03, 2.14099884e-03, 3.76105309e-03, 1.74236298e-03,
#        9.01699066e-04, 9.67025757e-04, 1.46031380e-03, 5.99360466e-03,
#        1.11508369e-03, 4.63294983e-03, 6.18934631e-04, 7.57694244e-04,
#        2.08139420e-03, 3.18551064e-03, 1.07431412e-03, 4.10366058e-03,
#        5.24234772e-03, 3.01599503e-03, 2.63810158e-03, 1.09004974e-03,
#        3.96656990e-03, 9.68694687e-04, 1.01613998e-03, 1.38187408e-03,
#        5.59091568e-04, 9.09090042e-04, 2.05206871e-03, 1.00727081e-02,
#        8.72445107e-03, 2.32315063e-03, 1.69420242e-03, 4.36592102e-03,
#        8.35895538e-04, 1.07710361e-02]))
# 0.988475
# [[0.0000000e+00 1.9999998e-02]
#  [5.8341129e-03 7.9999998e-04]
#  [1.6410720e-02 7.9999998e-04]
#  ...
#  [1.9999746e+00 7.9999998e-04]
#  [1.9999791e+00 7.9999998e-04]
#  [1.9999865e+00 7.9999998e-04]]

# %%
sEMDs, shape_events, losses = compute_single_event(dataset[0])

# # precompute
# with jax.profiler.trace("/tmp/jax-trace-123", create_perfetto_link=True):
#     sEMDs, shape_events, losses = compute_events(dataset[:50], 0.001, 150, finite_difference=False)



sEMDs, shape_events, losses = compute_events(dataset[:10000], 0.001, 150, finite_difference=False)

filename = f"{this_study}_sEMDs.npy"
save_dir = os.path.join(this_dir, filename)
np.save(save_dir, sEMDs)

filename = f"{this_study}_params.npy"
save_dir = os.path.join(this_dir, filename)
np.save(save_dir, shape_events["Radius"])

# plot the average loss per epoch
plt.plot(np.mean(losses, axis = -1))
# plt.yscale("log")
# Out:
# 100%|██████████| 150/150 [00:00<00:00, 567.00it/s]
# (10000, 2776, 2) (10000, 75, 3)
# 100%|██████████| 150/150 [1:27:20<00:00, 34.94s/it]

# %%
print(sEMDs.shape)
print(shape_events["Radius"])

# Function to take a list of points and create a histogram of points with sqrt(N) errors, normalized to unit area
def hist_with_errors(ax, points, bins, range, weights = None, **kwargs):

    if weights is None:
        weights = np.ones_like(points)

    hist, bin_edges = np.histogram(points, bins = bins, range = range, weights = weights)
    errs2 = np.histogram(points, bins = bins, range = range, weights = weights**2)[0] + 1

    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    bin_widths = (bin_edges[1:] - bin_edges[:-1])

    hist_tot = np.sum(hist * bin_widths)
    hist = hist / hist_tot
    errs2 = errs2 / (hist_tot**2)

    ax.errorbar(bin_centers, hist, np.sqrt(errs2), xerr = bin_widths, fmt = ".", **kwargs)



fig, ax = newplot()
hist_with_errors(ax, shape_events["Radius"], bins = 16, range = (0, 0.2), label = R"Full $SPECTER$")
hist_with_errors(ax, closed_form_r, bins = 16, range = (0, 0.2), label = R"Closed-Form $SPECTER$")

# plt.hist(shape_events["Radius"], bins = 16, range = (0, 1.6), density = True)
plt.xlabel("Radius [sPringiness]")
plt.ylabel("Normalized Counts")
plt.legend(frameon = False, loc = "upper left")
# Out:
# (10000,)
# [0.1        0.08662578 0.11772604 ... 0.08942613 0.07495885 0.07680769]

# %% [markdown]
# # Closed Form Expressions

# %%
# closed_form_sEMDs = closed_form_2_spronginess(dataset, levels = 150)
# print(closed_form_sEMDs)


# filename = f"{this_study}_closed_form_sEMDs.npy"
# save_dir = os.path.join(this_dir, filename)
# np.save(save_dir, closed_form_sEMDs)

# %% [markdown]
# # SHAPER

# %%
# SHAPER
from pyshaper.CommonObservables import buildCommmonObservables
from pyshaper.Observables import Observable
from pyshaper.Shaper import Shaper

# Necessary GPU nonsense
import torch 

if torch.cuda.is_available():  
    dev = "cuda:0" 
    print("Using GPU!")
else:  
    dev = "cpu"  
    print("Using CPU!")
device = torch.device(dev) 


# Generate new events

R = 1.0
N = 180
angles = np.linspace(0, np.pi, N)
energies = np.linspace(0, 1, N)

events = []
for i in range(dataset.shape[0]):

    event = dataset[i]

    zs = event[:,0]
    points = event[:,1:3]

    events.append((points, zs))


# EMDs

commonObservables, pointers = buildCommmonObservables(N = 3, beta = 2, R = R, device = device)
_2subjettiness = commonObservables["1-Point-Ringiness"]

# Default value
_2subjettiness.params["Radius1"] = _2subjettiness.params.pop("Radius")
_2subjettiness.params["Radius1"].default_value = torch.tensor([.5,])


def ring_sampler(N, param_dict):

        centers = param_dict["Points"].params
        num = param_dict["Points"].N
        radii = param_dict["Radius1"].params
        weights = param_dict["Weights"].params

        phi = 2 * np.pi * torch.rand(num, N).to(device)
        points = torch.stack([torch.cos(phi), torch.sin(phi)], axis=1) * radii[:, None, None] + centers[:, :, None]
        points = torch.cat([point for point in points], dim=1)

        # Concatenate and reweight
        e = points.T
        z = torch.cat([weights[i] * torch.ones((N,), device=device) / N for i in range(num)], dim=0)
        return (e, z)


_2subjettiness.sampler = ring_sampler

# Collect our observables in one dictionary
observables = {}
observables["1-Ringiness"] = _2subjettiness



# Initialize SHAPER
shaper = Shaper(observables, device)
shaper.to(device)


EMDs = []
params = []


dataset_emds, dataset_params = shaper.calculate(events, epochs = 500, verbose=True, lr = 0.01, N = 50, scaling = 0.9, epsilon = 0.001, early_stopping= 25)
for j in range(dataset.shape[0]):
    e = dataset_params["1-Ringiness"][j]["EMD"]
    EMDs.append(e)
    params.append(dataset_params["1-Ringiness"][j]["Radius1"])


EMDs = np.array(EMDs)
params = np.array(params)


plt.hist(params)
print(np.mean(params))

# filename = f"{this_study}_shaper_EMDs.npy"
# save_dir = os.path.join(this_dir, filename)
# np.save(save_dir, EMDs)

# filename = f"{this_study}_shaper_params.npy"
# save_dir = os.path.join(this_dir, filename)
# np.save(save_dir, params)
# Out:
# Using CPU!
# Observable: 1-Ringiness Epoch 0 Mean Loss = 2.58110627412796 Elapsed time = 0.784s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 1 Mean Loss = 2.519726173877716 Elapsed time = 1.516s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 2 Mean Loss = 2.460136935710907 Elapsed time = 2.286s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 3 Mean Loss = 2.401073040962219 Elapsed time = 3.024s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 4 Mean Loss = 2.34322053194046 Elapsed time = 3.793s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 5 Mean Loss = 2.286428682804108 Elapsed time = 4.537s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 6 Mean Loss = 2.230388996601105 Elapsed time = 5.286s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 7 Mean Loss = 2.175008716583252 Elapsed time = 6.018s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 8 Mean Loss = 2.120819699764252 Elapsed time = 6.755s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 9 Mean Loss = 2.0675853586196897 Elapsed time = 7.545s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 10 Mean Loss = 2.0143149089813233 Elapsed time = 8.290s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 11 Mean Loss = 1.9627425503730773 Elapsed time = 9.086s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 12 Mean Loss = 1.9129470205307006 Elapsed time = 9.839s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 13 Mean Loss = 1.8628725600242615 Elapsed time = 10.666s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 14 Mean Loss = 1.8132347893714904 Elapsed time = 11.624s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 15 Mean Loss = 1.7652965557575226 Elapsed time = 12.661s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 16 Mean Loss = 1.7190849924087523 Elapsed time = 13.524s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 17 Mean Loss = 1.6716899251937867 Elapsed time = 14.272s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 18 Mean Loss = 1.6266975843906402 Elapsed time = 15.066s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 19 Mean Loss = 1.5826619923114777 Elapsed time = 15.885s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 20 Mean Loss = 1.5389614689350128 Elapsed time = 16.732s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 21 Mean Loss = 1.496739821434021 Elapsed time = 17.550s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 22 Mean Loss = 1.4551044666767121 Elapsed time = 18.355s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 23 Mean Loss = 1.4134067344665526 Elapsed time = 19.339s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 24 Mean Loss = 1.3736511254310608 Elapsed time = 20.259s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 25 Mean Loss = 1.3336056315898894 Elapsed time = 21.066s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 26 Mean Loss = 1.2952736735343933 Elapsed time = 21.935s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 27 Mean Loss = 1.2580507159233094 Elapsed time = 22.647s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 28 Mean Loss = 1.220519312620163 Elapsed time = 23.377s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 29 Mean Loss = 1.1843127274513245 Elapsed time = 24.070s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 30 Mean Loss = 1.1496743834018708 Elapsed time = 24.766s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 31 Mean Loss = 1.1147912740707397 Elapsed time = 25.443s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 32 Mean Loss = 1.0811469662189483 Elapsed time = 26.143s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 33 Mean Loss = 1.0477480053901673 Elapsed time = 26.810s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 34 Mean Loss = 1.0162098181247712 Elapsed time = 27.493s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 35 Mean Loss = 0.9842576611042023 Elapsed time = 28.152s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 36 Mean Loss = 0.9539941668510437 Elapsed time = 28.880s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 37 Mean Loss = 0.9256963181495667 Elapsed time = 29.529s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 38 Mean Loss = 0.8953461742401123 Elapsed time = 30.176s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 39 Mean Loss = 0.8680768096446991 Elapsed time = 30.828s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 40 Mean Loss = 0.8410848522186279 Elapsed time = 31.471s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 41 Mean Loss = 0.8140081071853638 Elapsed time = 32.130s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 42 Mean Loss = 0.7879610347747803 Elapsed time = 32.767s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 43 Mean Loss = 0.7630931115150452 Elapsed time = 33.396s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 44 Mean Loss = 0.7395993614196777 Elapsed time = 34.060s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 45 Mean Loss = 0.7160177612304688 Elapsed time = 34.676s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 46 Mean Loss = 0.6934489703178406 Elapsed time = 35.356s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 47 Mean Loss = 0.6722236013412476 Elapsed time = 35.962s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 48 Mean Loss = 0.6520923662185669 Elapsed time = 36.686s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 49 Mean Loss = 0.6323526608943939 Elapsed time = 37.563s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 50 Mean Loss = 0.6145228350162506 Elapsed time = 38.180s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 51 Mean Loss = 0.5972660326957703 Elapsed time = 38.816s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 52 Mean Loss = 0.5803577613830566 Elapsed time = 39.441s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 53 Mean Loss = 0.5650184071063995 Elapsed time = 40.197s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 54 Mean Loss = 0.5489878594875336 Elapsed time = 40.817s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 55 Mean Loss = 0.5339372801780701 Elapsed time = 41.432s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 56 Mean Loss = 0.5187520623207093 Elapsed time = 42.068s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 57 Mean Loss = 0.5039215183258057 Elapsed time = 42.677s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 58 Mean Loss = 0.49010676860809327 Elapsed time = 43.302s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 59 Mean Loss = 0.47644893169403074 Elapsed time = 44.019s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 60 Mean Loss = 0.4632815170288086 Elapsed time = 44.621s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 61 Mean Loss = 0.4505368876457214 Elapsed time = 45.224s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 62 Mean Loss = 0.437920458316803 Elapsed time = 45.846s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 63 Mean Loss = 0.42595706701278685 Elapsed time = 46.516s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 64 Mean Loss = 0.41478153347969055 Elapsed time = 47.185s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 65 Mean Loss = 0.40300702571868896 Elapsed time = 47.839s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 66 Mean Loss = 0.392148118019104 Elapsed time = 48.524s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 67 Mean Loss = 0.3818463885784149 Elapsed time = 49.184s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 68 Mean Loss = 0.3711537265777588 Elapsed time = 49.915s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 69 Mean Loss = 0.3610383152961731 Elapsed time = 50.583s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 70 Mean Loss = 0.35127652645111085 Elapsed time = 51.286s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 71 Mean Loss = 0.34179867267608643 Elapsed time = 51.953s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 72 Mean Loss = 0.3330567634105682 Elapsed time = 52.625s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 73 Mean Loss = 0.3238036489486694 Elapsed time = 53.360s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 74 Mean Loss = 0.3146724760532379 Elapsed time = 54.033s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 75 Mean Loss = 0.3070076620578766 Elapsed time = 54.745s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 76 Mean Loss = 0.29820334672927856 Elapsed time = 55.424s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 77 Mean Loss = 0.2901107823848724 Elapsed time = 56.199s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 78 Mean Loss = 0.2825574028491974 Elapsed time = 56.874s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 79 Mean Loss = 0.2749283844232559 Elapsed time = 57.601s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 80 Mean Loss = 0.2676744347810745 Elapsed time = 58.281s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 81 Mean Loss = 0.26095280051231384 Elapsed time = 58.956s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 82 Mean Loss = 0.25434880673885346 Elapsed time = 59.631s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 83 Mean Loss = 0.24739172995090486 Elapsed time = 60.306s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 84 Mean Loss = 0.2413743978738785 Elapsed time = 60.974s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 85 Mean Loss = 0.23526578426361083 Elapsed time = 61.700s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 86 Mean Loss = 0.22879778742790222 Elapsed time = 62.364s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 87 Mean Loss = 0.222960866689682 Elapsed time = 63.045s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 88 Mean Loss = 0.2169805908203125 Elapsed time = 63.710s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 89 Mean Loss = 0.21096264719963073 Elapsed time = 64.387s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 90 Mean Loss = 0.2057546305656433 Elapsed time = 65.061s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 91 Mean Loss = 0.20115077316761018 Elapsed time = 65.738s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 92 Mean Loss = 0.19680359482765197 Elapsed time = 66.407s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 93 Mean Loss = 0.19133441746234894 Elapsed time = 67.078s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 94 Mean Loss = 0.18702347218990326 Elapsed time = 67.747s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 95 Mean Loss = 0.18217765152454377 Elapsed time = 68.437s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 96 Mean Loss = 0.17747023224830627 Elapsed time = 69.134s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 97 Mean Loss = 0.17335818886756896 Elapsed time = 69.813s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 98 Mean Loss = 0.1691769391298294 Elapsed time = 70.531s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 99 Mean Loss = 0.16520162642002106 Elapsed time = 71.222s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 100 Mean Loss = 0.1613298100233078 Elapsed time = 72.004s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 101 Mean Loss = 0.15769716560840608 Elapsed time = 72.665s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 102 Mean Loss = 0.15393392264842987 Elapsed time = 73.348s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 103 Mean Loss = 0.15018077075481415 Elapsed time = 74.010s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 104 Mean Loss = 0.1467050766944885 Elapsed time = 74.656s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 105 Mean Loss = 0.14383738458156586 Elapsed time = 75.372s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 106 Mean Loss = 0.14081718742847443 Elapsed time = 76.042s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 107 Mean Loss = 0.13807554244995118 Elapsed time = 76.750s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 108 Mean Loss = 0.13417454719543456 Elapsed time = 77.423s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 109 Mean Loss = 0.1316039401292801 Elapsed time = 78.087s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 110 Mean Loss = 0.1289696502685547 Elapsed time = 78.791s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 111 Mean Loss = 0.12616753220558166 Elapsed time = 79.456s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 112 Mean Loss = 0.12342667460441589 Elapsed time = 80.156s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 113 Mean Loss = 0.1206843900680542 Elapsed time = 80.846s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 114 Mean Loss = 0.11883466541767121 Elapsed time = 81.571s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 115 Mean Loss = 0.1162376981973648 Elapsed time = 82.245s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 116 Mean Loss = 0.11385706901550292 Elapsed time = 82.918s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 117 Mean Loss = 0.11125162780284882 Elapsed time = 83.609s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 118 Mean Loss = 0.10959231793880463 Elapsed time = 84.272s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 119 Mean Loss = 0.1076326060295105 Elapsed time = 85.008s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 120 Mean Loss = 0.10598960876464844 Elapsed time = 85.673s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 121 Mean Loss = 0.10367701411247253 Elapsed time = 86.372s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 122 Mean Loss = 0.1018079924583435 Elapsed time = 87.064s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 123 Mean Loss = 0.1001271253824234 Elapsed time = 87.728s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 124 Mean Loss = 0.09914038687944413 Elapsed time = 88.435s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 125 Mean Loss = 0.09696486622095107 Elapsed time = 89.100s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 126 Mean Loss = 0.09499814867973327 Elapsed time = 89.804s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 127 Mean Loss = 0.09395430475473404 Elapsed time = 90.466s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 128 Mean Loss = 0.09274880617856979 Elapsed time = 91.198s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 129 Mean Loss = 0.09068416476249695 Elapsed time = 91.859s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 130 Mean Loss = 0.08955143064260483 Elapsed time = 92.519s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 131 Mean Loss = 0.08859262228012085 Elapsed time = 93.229s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 132 Mean Loss = 0.08659161031246185 Elapsed time = 93.896s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 133 Mean Loss = 0.0852605226635933 Elapsed time = 94.613s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 134 Mean Loss = 0.08456443637609481 Elapsed time = 95.333s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 135 Mean Loss = 0.08300477176904679 Elapsed time = 96.070s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 136 Mean Loss = 0.08185037463903427 Elapsed time = 96.740s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 137 Mean Loss = 0.08099636971950532 Elapsed time = 97.405s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 138 Mean Loss = 0.07992073893547058 Elapsed time = 98.110s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 139 Mean Loss = 0.07873131960630417 Elapsed time = 98.790s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 140 Mean Loss = 0.07817723542451858 Elapsed time = 99.458s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 141 Mean Loss = 0.0776360335946083 Elapsed time = 100.165s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 142 Mean Loss = 0.07604860842227935 Elapsed time = 100.833s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 143 Mean Loss = 0.07520693987607956 Elapsed time = 101.497s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 144 Mean Loss = 0.07456856489181518 Elapsed time = 102.168s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 145 Mean Loss = 0.07321292042732239 Elapsed time = 102.843s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 146 Mean Loss = 0.07294483304023743 Elapsed time = 103.499s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 147 Mean Loss = 0.07167878657579423 Elapsed time = 104.165s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 148 Mean Loss = 0.0710119679570198 Elapsed time = 104.856s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 149 Mean Loss = 0.07111962050199509 Elapsed time = 105.530s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 150 Mean Loss = 0.07046888947486878 Elapsed time = 106.196s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 151 Mean Loss = 0.0700963118672371 Elapsed time = 106.863s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 152 Mean Loss = 0.06870450526475906 Elapsed time = 107.537s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 153 Mean Loss = 0.06871843248605729 Elapsed time = 108.201s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 154 Mean Loss = 0.06787318408489228 Elapsed time = 108.873s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 155 Mean Loss = 0.06766300290822982 Elapsed time = 109.526s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 156 Mean Loss = 0.06646528005599976 Elapsed time = 110.188s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 157 Mean Loss = 0.06650600954890251 Elapsed time = 110.855s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 158 Mean Loss = 0.06592054143548012 Elapsed time = 111.520s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 159 Mean Loss = 0.06532537057995796 Elapsed time = 112.191s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 160 Mean Loss = 0.06445131108164787 Elapsed time = 112.873s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 161 Mean Loss = 0.06411720275878906 Elapsed time = 113.537s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 162 Mean Loss = 0.0638193091750145 Elapsed time = 114.231s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 163 Mean Loss = 0.06365213260054588 Elapsed time = 114.892s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 164 Mean Loss = 0.06293887466192245 Elapsed time = 115.573s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 165 Mean Loss = 0.06215941160917282 Elapsed time = 116.239s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 166 Mean Loss = 0.06235409915447235 Elapsed time = 116.957s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 167 Mean Loss = 0.06165177538990974 Elapsed time = 117.618s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 168 Mean Loss = 0.0621361355483532 Elapsed time = 118.289s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 169 Mean Loss = 0.060866185575723646 Elapsed time = 118.951s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 170 Mean Loss = 0.06134025186300278 Elapsed time = 119.610s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 171 Mean Loss = 0.06037448137998581 Elapsed time = 120.281s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 172 Mean Loss = 0.061282659620046614 Elapsed time = 121.016s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 173 Mean Loss = 0.06003383710980415 Elapsed time = 121.694s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 174 Mean Loss = 0.05980826556682586 Elapsed time = 122.390s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 175 Mean Loss = 0.05952661663293839 Elapsed time = 123.059s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 176 Mean Loss = 0.05914358511567116 Elapsed time = 123.718s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 177 Mean Loss = 0.05901528760790825 Elapsed time = 124.388s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 178 Mean Loss = 0.05886325642466545 Elapsed time = 125.096s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 179 Mean Loss = 0.05892470732331276 Elapsed time = 125.758s Percentage done = 0.000
# Observable: 1-Ringiness Epoch 180 Mean Loss = 0.05850242957472801 Elapsed time = 126.430s Percentage done = 1.000
# Observable: 1-Ringiness Epoch 181 Mean Loss = 0.05890480920672417 Elapsed time = 127.095s Percentage done = 1.000
# Observable: 1-Ringiness Epoch 182 Mean Loss = 0.05762799397110939 Elapsed time = 127.774s Percentage done = 1.000
# Observable: 1-Ringiness Epoch 183 Mean Loss = 0.05843553245067597 Elapsed time = 128.427s Percentage done = 1.000
# Observable: 1-Ringiness Epoch 184 Mean Loss = 0.057464820593595506 Elapsed time = 129.077s Percentage done = 1.000
# Observable: 1-Ringiness Epoch 185 Mean Loss = 0.05800491496920586 Elapsed time = 129.744s Percentage done = 1.000
# Observable: 1-Ringiness Epoch 186 Mean Loss = 0.05745436549186707 Elapsed time = 130.411s Percentage done = 2.000
# Observable: 1-Ringiness Epoch 187 Mean Loss = 0.05765704452991485 Elapsed time = 131.065s Percentage done = 2.000
# Observable: 1-Ringiness Epoch 188 Mean Loss = 0.057203914672136306 Elapsed time = 131.782s Percentage done = 2.000
# Observable: 1-Ringiness Epoch 189 Mean Loss = 0.05752047315239906 Elapsed time = 132.445s Percentage done = 2.000
# Observable: 1-Ringiness Epoch 190 Mean Loss = 0.057392122074961666 Elapsed time = 133.127s Percentage done = 2.000
# Observable: 1-Ringiness Epoch 191 Mean Loss = 0.05682881124317646 Elapsed time = 133.784s Percentage done = 2.000
# Observable: 1-Ringiness Epoch 192 Mean Loss = 0.05585183024406433 Elapsed time = 134.481s Percentage done = 2.000
# Observable: 1-Ringiness Epoch 193 Mean Loss = 0.05625723846256733 Elapsed time = 135.143s Percentage done = 3.000
# Observable: 1-Ringiness Epoch 194 Mean Loss = 0.05677073173224926 Elapsed time = 135.793s Percentage done = 3.000
# Observable: 1-Ringiness Epoch 195 Mean Loss = 0.05605869270861149 Elapsed time = 136.441s Percentage done = 3.000
# Observable: 1-Ringiness Epoch 196 Mean Loss = 0.05615064956247807 Elapsed time = 137.096s Percentage done = 3.000
# Observable: 1-Ringiness Epoch 197 Mean Loss = 0.05648287676274776 Elapsed time = 137.768s Percentage done = 3.000
# Observable: 1-Ringiness Epoch 198 Mean Loss = 0.05606398515403271 Elapsed time = 138.420s Percentage done = 3.000
# Observable: 1-Ringiness Epoch 199 Mean Loss = 0.056190376058220866 Elapsed time = 139.081s Percentage done = 3.000
# Observable: 1-Ringiness Epoch 200 Mean Loss = 0.056037357673048974 Elapsed time = 139.714s Percentage done = 5.000
# Observable: 1-Ringiness Epoch 201 Mean Loss = 0.05599128685891628 Elapsed time = 140.344s Percentage done = 5.000
# Observable: 1-Ringiness Epoch 202 Mean Loss = 0.055888202413916586 Elapsed time = 140.962s Percentage done = 6.000
# Observable: 1-Ringiness Epoch 203 Mean Loss = 0.055814819410443306 Elapsed time = 141.590s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 204 Mean Loss = 0.055957264974713324 Elapsed time = 142.204s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 205 Mean Loss = 0.05579150050878525 Elapsed time = 142.802s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 206 Mean Loss = 0.05586028404533863 Elapsed time = 143.403s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 207 Mean Loss = 0.05531267873942852 Elapsed time = 144.018s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 208 Mean Loss = 0.05542409211397171 Elapsed time = 144.625s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 209 Mean Loss = 0.055341340452432636 Elapsed time = 145.235s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 210 Mean Loss = 0.05539341859519482 Elapsed time = 145.869s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 211 Mean Loss = 0.05586151875555515 Elapsed time = 146.478s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 212 Mean Loss = 0.05528852798044682 Elapsed time = 147.100s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 213 Mean Loss = 0.0553518208861351 Elapsed time = 147.707s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 214 Mean Loss = 0.055143459141254424 Elapsed time = 148.305s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 215 Mean Loss = 0.056147270761430265 Elapsed time = 148.917s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 216 Mean Loss = 0.05544745810329914 Elapsed time = 149.529s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 217 Mean Loss = 0.05559663537889719 Elapsed time = 150.205s Percentage done = 7.000
# Observable: 1-Ringiness Epoch 218 Mean Loss = 0.05495858609676361 Elapsed time = 150.759s Percentage done = 10.000
# Observable: 1-Ringiness Epoch 219 Mean Loss = 0.05517560947686434 Elapsed time = 151.324s Percentage done = 10.000
# Observable: 1-Ringiness Epoch 220 Mean Loss = 0.05513113237917423 Elapsed time = 151.897s Percentage done = 10.000
# Observable: 1-Ringiness Epoch 221 Mean Loss = 0.05562255539000034 Elapsed time = 152.459s Percentage done = 11.000
# Observable: 1-Ringiness Epoch 222 Mean Loss = 0.055317740440368655 Elapsed time = 153.032s Percentage done = 12.000
# Observable: 1-Ringiness Epoch 223 Mean Loss = 0.05500678963959217 Elapsed time = 153.611s Percentage done = 12.000
# Observable: 1-Ringiness Epoch 224 Mean Loss = 0.05492729023098945 Elapsed time = 154.185s Percentage done = 12.000
# Observable: 1-Ringiness Epoch 225 Mean Loss = 0.055408351086080075 Elapsed time = 154.744s Percentage done = 14.000
# Observable: 1-Ringiness Epoch 226 Mean Loss = 0.055485915206372735 Elapsed time = 155.342s Percentage done = 15.000
# Observable: 1-Ringiness Epoch 227 Mean Loss = 0.05516310103237629 Elapsed time = 155.887s Percentage done = 16.000
# Observable: 1-Ringiness Epoch 228 Mean Loss = 0.054906851947307586 Elapsed time = 156.440s Percentage done = 16.000
# Observable: 1-Ringiness Epoch 229 Mean Loss = 0.054968645684421065 Elapsed time = 156.984s Percentage done = 16.000
# Observable: 1-Ringiness Epoch 230 Mean Loss = 0.05525940142571926 Elapsed time = 157.541s Percentage done = 16.000
# Observable: 1-Ringiness Epoch 231 Mean Loss = 0.05470863126218319 Elapsed time = 158.082s Percentage done = 16.000
# Observable: 1-Ringiness Epoch 232 Mean Loss = 0.05497917141765356 Elapsed time = 158.633s Percentage done = 16.000
# Observable: 1-Ringiness Epoch 233 Mean Loss = 0.05546021763235331 Elapsed time = 159.282s Percentage done = 16.000
# Observable: 1-Ringiness Epoch 234 Mean Loss = 0.05448262669146061 Elapsed time = 159.878s Percentage done = 18.000
# Observable: 1-Ringiness Epoch 235 Mean Loss = 0.05520619336515665 Elapsed time = 160.503s Percentage done = 18.000
# Observable: 1-Ringiness Epoch 236 Mean Loss = 0.05511905141174793 Elapsed time = 161.056s Percentage done = 18.000
# Observable: 1-Ringiness Epoch 237 Mean Loss = 0.054820750169456006 Elapsed time = 161.785s Percentage done = 19.000
# Observable: 1-Ringiness Epoch 238 Mean Loss = 0.05493956036865711 Elapsed time = 162.316s Percentage done = 20.000
# Observable: 1-Ringiness Epoch 239 Mean Loss = 0.05480208225548267 Elapsed time = 162.835s Percentage done = 23.000
# Observable: 1-Ringiness Epoch 240 Mean Loss = 0.05466332506388426 Elapsed time = 163.389s Percentage done = 25.000
# Observable: 1-Ringiness Epoch 241 Mean Loss = 0.054505746569484474 Elapsed time = 164.077s Percentage done = 27.000
# Observable: 1-Ringiness Epoch 242 Mean Loss = 0.0550251879170537 Elapsed time = 164.690s Percentage done = 27.000
# Observable: 1-Ringiness Epoch 243 Mean Loss = 0.05487849783152342 Elapsed time = 165.197s Percentage done = 27.000
# Observable: 1-Ringiness Epoch 244 Mean Loss = 0.0544741684384644 Elapsed time = 165.685s Percentage done = 28.000
# Observable: 1-Ringiness Epoch 245 Mean Loss = 0.05449147881940007 Elapsed time = 166.185s Percentage done = 30.000
# Observable: 1-Ringiness Epoch 246 Mean Loss = 0.05479021105915308 Elapsed time = 166.721s Percentage done = 31.000
# Observable: 1-Ringiness Epoch 247 Mean Loss = 0.05452765518799424 Elapsed time = 167.424s Percentage done = 33.000
# Observable: 1-Ringiness Epoch 248 Mean Loss = 0.05470061060041189 Elapsed time = 167.941s Percentage done = 35.000
# Observable: 1-Ringiness Epoch 249 Mean Loss = 0.054293131176382306 Elapsed time = 168.489s Percentage done = 35.000
# Observable: 1-Ringiness Epoch 250 Mean Loss = 0.05497563792392612 Elapsed time = 168.945s Percentage done = 37.000
# Observable: 1-Ringiness Epoch 251 Mean Loss = 0.05452425478026271 Elapsed time = 169.437s Percentage done = 39.000
# Observable: 1-Ringiness Epoch 252 Mean Loss = 0.05462107030674815 Elapsed time = 169.903s Percentage done = 40.000
# Observable: 1-Ringiness Epoch 253 Mean Loss = 0.054893399998545644 Elapsed time = 170.306s Percentage done = 40.000
# Observable: 1-Ringiness Epoch 254 Mean Loss = 0.05462197145447135 Elapsed time = 170.716s Percentage done = 40.000
# Observable: 1-Ringiness Epoch 255 Mean Loss = 0.05457327799871564 Elapsed time = 171.142s Percentage done = 41.000
# Observable: 1-Ringiness Epoch 256 Mean Loss = 0.054512707628309724 Elapsed time = 171.535s Percentage done = 43.000
# Observable: 1-Ringiness Epoch 257 Mean Loss = 0.05461907662451267 Elapsed time = 171.919s Percentage done = 48.000
# Observable: 1-Ringiness Epoch 258 Mean Loss = 0.05470780609175563 Elapsed time = 172.352s Percentage done = 48.000
# Observable: 1-Ringiness Epoch 259 Mean Loss = 0.05451428705826402 Elapsed time = 172.740s Percentage done = 48.000
# Observable: 1-Ringiness Epoch 260 Mean Loss = 0.05464945927262306 Elapsed time = 173.089s Percentage done = 51.000
# Observable: 1-Ringiness Epoch 261 Mean Loss = 0.054736534990370275 Elapsed time = 173.419s Percentage done = 53.000
# Observable: 1-Ringiness Epoch 262 Mean Loss = 0.05454649046063423 Elapsed time = 173.734s Percentage done = 57.000
# Observable: 1-Ringiness Epoch 263 Mean Loss = 0.05460593668743968 Elapsed time = 174.086s Percentage done = 58.000
# Observable: 1-Ringiness Epoch 264 Mean Loss = 0.0548313020914793 Elapsed time = 174.394s Percentage done = 60.000
# Observable: 1-Ringiness Epoch 265 Mean Loss = 0.05449356289580464 Elapsed time = 174.702s Percentage done = 62.000
# Observable: 1-Ringiness Epoch 266 Mean Loss = 0.054302078122273084 Elapsed time = 175.021s Percentage done = 62.000
# Observable: 1-Ringiness Epoch 267 Mean Loss = 0.054281197655946016 Elapsed time = 175.298s Percentage done = 64.000
# Observable: 1-Ringiness Epoch 268 Mean Loss = 0.05458968768827617 Elapsed time = 175.557s Percentage done = 68.000
# Observable: 1-Ringiness Epoch 269 Mean Loss = 0.054729067888110876 Elapsed time = 175.784s Percentage done = 71.000
# Observable: 1-Ringiness Epoch 270 Mean Loss = 0.05480023657903075 Elapsed time = 175.990s Percentage done = 74.000
# Observable: 1-Ringiness Epoch 271 Mean Loss = 0.05465220900252461 Elapsed time = 176.191s Percentage done = 74.000
# Observable: 1-Ringiness Epoch 272 Mean Loss = 0.05463986412622034 Elapsed time = 176.391s Percentage done = 75.000
# Observable: 1-Ringiness Epoch 273 Mean Loss = 0.05469188574701547 Elapsed time = 176.590s Percentage done = 76.000
# Observable: 1-Ringiness Epoch 274 Mean Loss = 0.05466042175889015 Elapsed time = 176.797s Percentage done = 77.000
# Observable: 1-Ringiness Epoch 275 Mean Loss = 0.054696568204089996 Elapsed time = 176.954s Percentage done = 82.000
# Observable: 1-Ringiness Epoch 276 Mean Loss = 0.05476099736057222 Elapsed time = 177.111s Percentage done = 83.000
# Observable: 1-Ringiness Epoch 277 Mean Loss = 0.05477904585190117 Elapsed time = 177.272s Percentage done = 85.000
# Observable: 1-Ringiness Epoch 278 Mean Loss = 0.054628168968483805 Elapsed time = 177.416s Percentage done = 86.000
# Observable: 1-Ringiness Epoch 279 Mean Loss = 0.05475543153472245 Elapsed time = 177.558s Percentage done = 86.000
# Observable: 1-Ringiness Epoch 280 Mean Loss = 0.054640727415680886 Elapsed time = 177.695s Percentage done = 87.000
# Observable: 1-Ringiness Epoch 281 Mean Loss = 0.05466932659968734 Elapsed time = 177.828s Percentage done = 88.000
# Observable: 1-Ringiness Epoch 282 Mean Loss = 0.054702158626168965 Elapsed time = 177.963s Percentage done = 89.000
# Observable: 1-Ringiness Epoch 283 Mean Loss = 0.05465631896629929 Elapsed time = 178.086s Percentage done = 89.000
# Observable: 1-Ringiness Epoch 284 Mean Loss = 0.054675912046805025 Elapsed time = 178.211s Percentage done = 89.000
# Observable: 1-Ringiness Epoch 285 Mean Loss = 0.05470019510015845 Elapsed time = 178.333s Percentage done = 89.000
# Observable: 1-Ringiness Epoch 286 Mean Loss = 0.05468316468410194 Elapsed time = 178.458s Percentage done = 90.000
# Observable: 1-Ringiness Epoch 287 Mean Loss = 0.05466753645334393 Elapsed time = 178.573s Percentage done = 90.000
# Observable: 1-Ringiness Epoch 288 Mean Loss = 0.05465415619313717 Elapsed time = 178.690s Percentage done = 90.000
# Observable: 1-Ringiness Epoch 289 Mean Loss = 0.05466351068578661 Elapsed time = 178.802s Percentage done = 91.000
# Observable: 1-Ringiness Epoch 290 Mean Loss = 0.05464459739625454 Elapsed time = 178.909s Percentage done = 91.000
# Observable: 1-Ringiness Epoch 291 Mean Loss = 0.05468225871678442 Elapsed time = 179.014s Percentage done = 91.000
# Observable: 1-Ringiness Epoch 292 Mean Loss = 0.0546646835654974 Elapsed time = 179.110s Percentage done = 92.000
# Observable: 1-Ringiness Epoch 293 Mean Loss = 0.05464580561965704 Elapsed time = 179.205s Percentage done = 93.000
# Done!
# 0.040097937

# %% [markdown]
# # Plots

# %%
fig, ax = newplot()

# Load numpy data
sEMDs = np.load(os.path.join(this_dir, f"{this_study}_sEMDs.npy"))
closed_form_sEMDs = np.load(os.path.join(this_dir, f"{this_study}_closed_form_sEMDs.npy"))
EMDs = np.load(os.path.join(this_dir, f"{this_study}_shaper_EMDs.npy"))


plt.scatter(2 * EMDs**2, closed_form_sEMDs, color = "red", alpha = 0.5)
plt.scatter(2 * EMDs**2,  sEMDs, color = "blue", alpha = 0.5)



plt.xscale("log")
plt.yscale("log")
plt.xlabel("2-Subjettiness ($SHAPER$)")
plt.ylabel("2-Sprubjetiness ($SPECTER$)")

# Dashed line at y = x
x = np.linspace(0, np.max(sEMDs), 100)
plt.plot(x, x, linestyle = "--", color = "black")

# print the MSE in the top left
mse = np.mean((np.maximum(sEMDs, 0) - closed_form_sEMDs)**2)
plt.text(0.05, 0.95, "MSE: %.3e\n1000 Events" % mse, transform=ax.transAxes, fontsize=14,)

# print the percentage of events that differ by more than temp1%
diff = (sEMDs - (2 * EMDs**2)) / (2 * EMDs**2)
print(np.sum(diff > 0.10))
# plt.scatter(np.maximum(sEMDs, 0)[diff > 0.10], closed_form_sEMDs[diff > 0.10])

# ax.set_aspect('equal')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/rikab/Documents/Research/SPECTER/Studies/ringiness/ringiness_cms.ipynb Cell 15 line 5
#       <a href='vscode-notebook-cell:/home/rikab/Documents/Research/SPECTER/Studies/ringiness/ringiness_cms.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> # Load numpy data
#       <a href='vscode-notebook-cell:/home/rikab/Documents/Research/SPECTER/Studies/ringiness/ringiness_cms.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> sEMDs = np.load(os.path.join(this_dir, f"{this_study}_sEMDs.npy"))
# ----> <a href='vscode-notebook-cell:/home/rikab/Documents/Research/SPECTER/Studies/ringiness/ringiness_cms.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> closed_form_sEMDs = np.load(os.path.join(this_dir, f"{this_study}_closed_form_sEMDs.npy"))
#       <a href='vscode-notebook-cell:/home/rikab/Documents/Research/SPECTER/Studies/ringiness/ringiness_cms.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> EMDs = np.load(os.path.join(this_dir, f"{this_study}_shaper_EMDs.npy"))
#       <a href='vscode-notebook-cell:/home/rikab/Documents/Research/SPECTER/Studies/ringiness/ringiness_cms.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> plt.scatter(2 * EMDs**2, closed_form_sEMDs, color = "red", alpha = 0.5)
#
# File ~/miniconda3/envs/SHAPER/lib/python3.8/site-packages/numpy/lib/npyio.py:407, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     405     own_fid = False
#     406 else:
# --> 407     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     408     own_fid = True
#     410 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cmsopendata_closed_form_sEMDs.npy'

# %%
# Plot a histogram of the differences
fig, ax = newplot()
plt.hist(diff, bins = 50 )

# plt.xscale("log")
plt.yscale("log")

plt.xlabel("Fractional Error")
